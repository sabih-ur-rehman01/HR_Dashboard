# %% [markdown]
# # HR Dataset Preprocessing & Dashboard

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
import plotly.express as px

# %%
df = pd.read_csv(r'HR_comma_sep (1).csv')
df
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 1                0.80             0.86               5                   262
# 2                0.11             0.88               7                   272
# 3                0.72             0.87               5                   223
# 4                0.37             0.52               2                   159
# 5                0.41             0.50               2                   153
# 6                0.10             0.77               6                   247
# 7                0.92             0.85               5                   259
# 8                0.89             1.00               5                   224
# 9                0.42             0.53               2                   142
#
#    time_spend_company  Work_accident  left  promotion_last_5years Department  \
# 0                   3              0     1                      0      sales
# 1                   6              0     1                      0      sales
# 2                   4              0     1                      0      sales
# 3                   5              0     1                      0      sales
# 4                   3              0     1                      0      sales
# 5                   3              0     1                      0      sales
# 6                   4              0     1                      0      sales
# 7                   5              0     1                      0      sales
# 8                   5              0     1                      0      sales
# 9                   3              0     1                      0      sales
#
#    salary
# 0     low
# 1  medium
# 2  medium
# 3     low
# 4     low
# 5     low
# 6     low
# 7     low
# 8     low
# 9     low

# %%
df.info()
df.describe()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 14999 entries, 0 to 14998
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   satisfaction_level     14999 non-null  float64
#  1   last_evaluation        14999 non-null  float64
#  2   number_project         14999 non-null  int64
#  3   average_montly_hours   14999 non-null  int64
#  4   time_spend_company     14999 non-null  int64
#  5   Work_accident          14999 non-null  int64
#  6   left                   14999 non-null  int64
#  7   promotion_last_5years  14999 non-null  int64
#  8   Department             14999 non-null  str
#  9   salary                 14999 non-null  str
# dtypes: float64(2), int64(6), str(2)
# memory usage: 1.3 MB
#        satisfaction_level  last_evaluation  number_project  \
# count        14999.000000     14999.000000    14999.000000
# mean             0.612834         0.716102        3.803054
# std              0.248631         0.171169        1.232592
# min              0.090000         0.360000        2.000000
# 25%              0.440000         0.560000        3.000000
# 50%              0.640000         0.720000        4.000000
# 75%              0.820000         0.870000        5.000000
# max              1.000000         1.000000        7.000000
#
#        average_montly_hours  time_spend_company  Work_accident          left  \
# count          14999.000000        14999.000000   14999.000000  14999.000000
# mean             201.050337            3.498233       0.144610      0.238083
# std               49.943099            1.460136       0.351719      0.425924
# min               96.000000            2.000000       0.000000      0.000000
# 25%              156.000000            3.000000       0.000000      0.000000
# 50%              200.000000            3.000000       0.000000      0.000000
# 75%              245.000000            4.000000       0.000000      0.000000
# max              310.000000           10.000000       1.000000      1.000000
#
#        promotion_last_5years
# count           14999.000000
# mean                0.021268
# std                 0.144281
# min                 0.000000
# 25%                 0.000000
# 50%                 0.000000
# 75%                 0.000000
# max                 1.000000

# %%
df.drop(['last_evaluation','Work_accident','promotion_last_5years','left'], axis=1, inplace=True)
df
# Out:
#        satisfaction_level  number_project  average_montly_hours  \
# 0                    0.38               2                   157
# 1                    0.80               5                   262
# 2                    0.11               7                   272
# 3                    0.72               5                   223
# 4                    0.37               2                   159
# ...                   ...             ...                   ...
# 14994                0.40               2                   151
# 14995                0.37               2                   160
# 14996                0.37               2                   143
# 14997                0.11               6                   280
# 14998                0.37               2                   158
#
#        time_spend_company Department  salary
# 0                       3      sales     low
# 1                       6      sales  medium
# 2                       4      sales  medium
# 3                       5      sales     low
# 4                       3      sales     low
# ...                   ...        ...     ...
# 14994                   3    support     low
# 14995                   3    support     low
# 14996                   3    support     low
# 14997                   4    support     low
# 14998                   3    support     low
#
# [14999 rows x 6 columns]

# %%
df.duplicated().sum()
# Out:
# np.int64(3125)

# %%
df.drop_duplicates(inplace=True)
df
# Out:
#        satisfaction_level  number_project  average_montly_hours  \
# 0                    0.38               2                   157
# 1                    0.80               5                   262
# 2                    0.11               7                   272
# 3                    0.72               5                   223
# 4                    0.37               2                   159
# ...                   ...             ...                   ...
# 11995                0.90               3                   259
# 11996                0.74               5                   266
# 11997                0.85               3                   185
# 11998                0.33               3                   172
# 11999                0.50               4                   180
#
#        time_spend_company  Department  salary
# 0                       3       sales     low
# 1                       6       sales  medium
# 2                       4       sales  medium
# 3                       5       sales     low
# 4                       3       sales     low
# ...                   ...         ...     ...
# 11995                  10  management    high
# 11996                  10  management    high
# 11997                  10  management    high
# 11998                  10   marketing    high
# 11999                   3          IT     low
#
# [11874 rows x 6 columns]

# %%
df.isnull().sum()
# Out:
# satisfaction_level      0
# number_project          0
# average_montly_hours    0
# time_spend_company      0
# Department              0
# salary                  0
# dtype: int64

# %%
df = pd.get_dummies(df, columns=['Department'], drop_first=True)

mapping = {'low': 15000, 'medium': 30000, 'high': 60000}
df['salary'] = df['salary'].map(mapping)
df
# Out:
#        satisfaction_level  number_project  average_montly_hours  \
# 0                    0.38               2                   157
# 1                    0.80               5                   262
# 2                    0.11               7                   272
# 3                    0.72               5                   223
# 4                    0.37               2                   159
# ...                   ...             ...                   ...
# 11995                0.90               3                   259
# 11996                0.74               5                   266
# 11997                0.85               3                   185
# 11998                0.33               3                   172
# 11999                0.50               4                   180
#
#        time_spend_company  salary  Department_RandD  Department_accounting  \
# 0                       3   15000             False                  False
# 1                       6   30000             False                  False
# 2                       4   30000             False                  False
# 3                       5   15000             False                  False
# 4                       3   15000             False                  False
# ...                   ...     ...               ...                    ...
# 11995                  10   60000             False                  False
# 11996                  10   60000             False                  False
# 11997                  10   60000             False                  False
# 11998                  10   60000             False                  False
# 11999                   3   15000             False                  False
#
#        Department_hr  Department_management  Department_marketing  \
# 0              False                  False                 False
# 1              False                  False                 False
# 2              False                  False                 False
# 3              False                  False                 False
# 4              False                  False                 False
# ...              ...                    ...                   ...
# 11995          False                   True                 False
# 11996          False                   True                 False
# 11997          False                   True                 False
# 11998          False                  False                  True
# 11999          False                  False                 False
#
#        Department_product_mng  Department_sales  Department_support  \
# 0                       False              True               False
# 1                       False              True               False
# 2                       False              True               False
# 3                       False              True               False
# 4                       False              True               False
# ...                       ...               ...                 ...
# 11995                   False             False               False
# 11996                   False             False               False
# 11997                   False             False               False
# 11998                   False             False               False
# 11999                   False             False               False
#
#        Department_technical
# 0                     False
# 1                     False
# 2                     False
# 3                     False
# 4                     False
# ...                     ...
# 11995                 False
# 11996                 False
# 11997                 False
# 11998                 False
# 11999                 False
#
# [11874 rows x 14 columns]

# %%
scaler = StandardScaler()
num_cols = ['satisfaction_level','number_project','average_montly_hours','time_spend_company']
df[num_cols] = scaler.fit_transform(df[num_cols])
df
# Out:
#        satisfaction_level  number_project  average_montly_hours  \
# 0               -1.044499       -1.562173             -0.895621
# 1                0.701109        1.030676              1.262668
# 2               -2.166676        2.759242              1.468219
# 3                0.368613        1.030676              0.461017
# 4               -1.086061       -1.562173             -0.854511
# ...                   ...             ...                   ...
# 11995            1.116730       -0.697890              1.201002
# 11996            0.451737        1.030676              1.344888
# 11997            0.908920       -0.697890             -0.320078
# 11998           -1.252310       -0.697890             -0.587294
# 11999           -0.545754        0.166393             -0.422853
#
#        time_spend_company  salary  Department_RandD  Department_accounting  \
# 0               -0.274590   15000             False                  False
# 1                1.972984   30000             False                  False
# 2                0.474601   30000             False                  False
# 3                1.223793   15000             False                  False
# 4               -0.274590   15000             False                  False
# ...                   ...     ...               ...                    ...
# 11995            4.969750   60000             False                  False
# 11996            4.969750   60000             False                  False
# 11997            4.969750   60000             False                  False
# 11998            4.969750   60000             False                  False
# 11999           -0.274590   15000             False                  False
#
#        Department_hr  Department_management  Department_marketing  \
# 0              False                  False                 False
# 1              False                  False                 False
# 2              False                  False                 False
# 3              False                  False                 False
# 4              False                  False                 False
# ...              ...                    ...                   ...
# 11995          False                   True                 False
# 11996          False                   True                 False
# 11997          False                   True                 False
# 11998          False                  False                  True
# 11999          False                  False                 False
#
#        Department_product_mng  Department_sales  Department_support  \
# 0                       False              True               False
# 1                       False              True               False
# 2                       False              True               False
# 3                       False              True               False
# 4                       False              True               False
# ...                       ...               ...                 ...
# 11995                   False             False               False
# 11996                   False             False               False
# 11997                   False             False               False
# 11998                   False             False               False
# 11999                   False             False               False
#
#        Department_technical
# 0                     False
# 1                     False
# 2                     False
# 3                     False
# 4                     False
# ...                     ...
# 11995                 False
# 11996                 False
# 11997                 False
# 11998                 False
# 11999                 False
#
# [11874 rows x 14 columns]

# %%
col = ['satisfaction_level','number_project','average_montly_hours','time_spend_company']
Q1 = df[col].quantile(0.25)
Q3 = df[col].quantile(0.75)
IQR = Q3 - Q1

lower = Q1 - 1.5 * IQR
upper = Q3 + 1.5 * IQR

outliers = ((df[col] < (Q1 - 1.5 * IQR)) | (df[col] > (Q3 + 1.5 * IQR)))

print("Outliers per column:\n", outliers.sum())
# Out:
# Outliers per column:
#  satisfaction_level        0
# number_project            0
# average_montly_hours      0
# time_spend_company      823
# dtype: int64

# %%
df[col] = df[col].clip(lower, upper, axis=1)
df
# Out:
#        satisfaction_level  number_project  average_montly_hours  \
# 0               -1.044499       -1.562173             -0.895621
# 1                0.701109        1.030676              1.262668
# 2               -2.166676        2.759242              1.468219
# 3                0.368613        1.030676              0.461017
# 4               -1.086061       -1.562173             -0.854511
# ...                   ...             ...                   ...
# 11995            1.116730       -0.697890              1.201002
# 11996            0.451737        1.030676              1.344888
# 11997            0.908920       -0.697890             -0.320078
# 11998           -1.252310       -0.697890             -0.587294
# 11999           -0.545754        0.166393             -0.422853
#
#        time_spend_company  salary  Department_RandD  Department_accounting  \
# 0               -0.274590   15000             False                  False
# 1                1.598388   30000             False                  False
# 2                0.474601   30000             False                  False
# 3                1.223793   15000             False                  False
# 4               -0.274590   15000             False                  False
# ...                   ...     ...               ...                    ...
# 11995            1.598388   60000             False                  False
# 11996            1.598388   60000             False                  False
# 11997            1.598388   60000             False                  False
# 11998            1.598388   60000             False                  False
# 11999           -0.274590   15000             False                  False
#
#        Department_hr  Department_management  Department_marketing  \
# 0              False                  False                 False
# 1              False                  False                 False
# 2              False                  False                 False
# 3              False                  False                 False
# 4              False                  False                 False
# ...              ...                    ...                   ...
# 11995          False                   True                 False
# 11996          False                   True                 False
# 11997          False                   True                 False
# 11998          False                  False                  True
# 11999          False                  False                 False
#
#        Department_product_mng  Department_sales  Department_support  \
# 0                       False              True               False
# 1                       False              True               False
# 2                       False              True               False
# 3                       False              True               False
# 4                       False              True               False
# ...                       ...               ...                 ...
# 11995                   False             False               False
# 11996                   False             False               False
# 11997                   False             False               False
# 11998                   False             False               False
# 11999                   False             False               False
#
#        Department_technical
# 0                     False
# 1                     False
# 2                     False
# 3                     False
# 4                     False
# ...                     ...
# 11995                 False
# 11996                 False
# 11997                 False
# 11998                 False
# 11999                 False
#
# [11874 rows x 14 columns]

# %%
fig1 = px.histogram(df,x='salary',title='Salary Distribution',color='salary')
fig1.update_layout( yaxis_title='Number of Employees')
fig1.show()

fig2 = px.box(df, x='salary', y='satisfaction_level', title='Satisfaction vs Salary',color='salary')
fig2.show()

fig3 = px.box(df, x='salary', y='number_project', title='Projects vs Salary',color='salary')
fig3.show()

fig4 = px.scatter(df, x='average_montly_hours', y='salary',title='Working Hours vs Salary', color='salary')
fig4.show()
